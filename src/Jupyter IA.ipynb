# %% [markdown]
# ## Run the current model

# %%
# %run 'init_or_load_then_train_main.py'
# Out:
# image batch: <class 'numpy.ndarray'>
# label batch: <class 'numpy.ndarray'>
# image batch: <class 'numpy.ndarray'>
# label batch: <class 'numpy.ndarray'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/PycharmProjects/T-DEV-810/src/init_or_load_then_train_main.py in <module>
#      30
#      31     # train model then evaluate with test data
# ---> 32     model.train(train_data, train_label, test_data, test_label, EPOCHS)
#      33     # save model in a .h5 file
#      34     model.save()
#
# ~/PycharmProjects/T-DEV-810/src/models/cnn_model.py in train(self, train_data, train_label, test_data, test_label, epochNumber)
#      37         # train model
#      38         if self.active_log:
# ---> 39             self.model.fit(train_data, train_label, validation_data=(test_data, test_label), epochs=epochNumber, callbacks=[self.tensorboard_callback])
#      40         else:
# ...

# %% [raw]
# All the logs

# %%
# %tensorboard --logdir logs/fit
# Out:
#       <iframe id="tensorboard-frame-6c102e11ef5ad902" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6c102e11ef5ad902");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
